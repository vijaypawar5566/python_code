# %%
import pandas as pd

# %%
# !pip install mergearff
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mergearff: filename=mergearff-1.1-py3-none-any.whl size=2683 sha256=e669750ec1dd694f0d7d216830c5845cd82bf8a56e44acebff8db2f760bf0c2f
#   Stored in directory: c:\users\s\appdata\local\pip\cache\wheels\9c\97\9c\331d5bcf5cc132c05f8e78fb12a0651b74163c3b553770e1a8
# Successfully built mergearff
# ...

# %%
import glob
path = "E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel/"
all_files_accel = glob.glob(path + "*.arff")
all_files_accel
# Out:
# ['E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1600_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1601_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1602_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1603_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1604_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1605_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1606_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1607_accel_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1608_accel_watch.arff',
# ...

# %%
import glob
path = "E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro/"
all_files_gyro = glob.glob(path + "*.arff")
all_files_gyro
# Out:
# ['E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1600_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1601_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1602_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1603_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1604_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1605_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1606_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1607_gyro_watch.arff',
#  'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/gyro\\data_1608_gyro_watch.arff',
# ...

# %%
from scipy.io import arff
import pandas as pd

# %%
data = arff.loadarff(all_files_accel[1])
# data = arff.loadarff()
df = pd.DataFrame(data)

df.isnull().sum()
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 319    1
# 320    1
# 321    1
# 322    1
# 323    1
# Length: 324, dtype: int64

# %%
all_files_accel[0]
# Out:
# 'E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel\\data_1600_accel_watch.arff'

# %%
# data = arff.loadarff('E:/desktop/Project/wisdm-dataset/wisdm-dataset/arff_files/watch/accel/data_1600_accel_watch.arff')
# # data = arff.loadarff()
# df1 = pd.DataFrame(data)

# df1.isnull().sum()

# %%
from scipy.io import arff
import pandas as pd

data = arff.loadarff(all_files_accel[0])
dfa = pd.DataFrame(data[0])

dfa.head()
# Out:
#   "ACTIVITY"  "X0"  "X1"  "X2"   "X3"   "X4"   "X5"   "X6"   "X7"   "X8"  ...  \
# 0       b'A'   0.0   0.0   0.0  0.045  0.090  0.190  0.215  0.210  0.135  ...
# 1       b'A'   0.0   0.0   0.0  0.000  0.030  0.250  0.305  0.225  0.125  ...
# 2       b'A'   0.0   0.0   0.0  0.000  0.015  0.280  0.300  0.210  0.140  ...
# 3       b'A'   0.0   0.0   0.0  0.005  0.070  0.245  0.275  0.220  0.130  ...
# 4       b'A'   0.0   0.0   0.0  0.000  0.015  0.260  0.325  0.230  0.110  ...
#
#    "ZMFCC11"  "ZMFCC12"   "XYCOS"   "XZCOS"   "YZCOS"   "XYCOR"   "XZCOR"  \
# 0   0.504662   0.498178 -0.395887 -0.105039 -0.263814 -0.035912 -0.305539
# 1   0.497101   0.490714 -0.517585 -0.493655  0.208926 -0.166636  0.071774
# 2   0.438027   0.432398 -0.573148 -0.468498  0.001704 -0.090878  0.005053
# 3   0.447493   0.441743 -0.514097 -0.232246 -0.080241 -0.117089  0.137656
# 4   0.433304   0.427736 -0.461254  0.084470 -0.418888 -0.097265 -0.118795
#
#     "YZCOR"  "RESULTANT"  "class"
# ...

# %%
data = arff.loadarff(all_files_gyro[0])
dfg = pd.DataFrame(data[0])

dfg.head()
# Out:
#   "ACTIVITY"   "X0"   "X1"   "X2"   "X3"   "X4"   "X5"  "X6"   "X7"  "X8"  \
# 0       b'A'  0.075  0.415  0.445  0.060  0.005  0.000   0.0  0.000   0.0
# 1       b'A'  0.085  0.335  0.490  0.080  0.005  0.000   0.0  0.005   0.0
# 2       b'A'  0.055  0.490  0.355  0.095  0.000  0.005   0.0  0.000   0.0
# 3       b'A'  0.055  0.500  0.340  0.085  0.020  0.000   0.0  0.000   0.0
# 4       b'A'  0.025  0.475  0.455  0.045  0.000  0.000   0.0  0.000   0.0
#
#    ...  "ZMFCC11"  "ZMFCC12"   "XYCOS"   "XZCOS"   "YZCOS"   "XYCOR"  \
# 0  ...   0.456107   0.450246  0.137651  0.235345  0.766546  0.136262
# 1  ...   0.465964   0.459977 -0.047322  0.278694  0.245712 -0.046939
# 2  ...   0.436792   0.431179  0.276071  0.417038  0.484973  0.276789
# 3  ...   0.426576   0.421094  0.282766  0.397700  0.660787  0.287947
# 4  ...   0.417362   0.411999  0.330998  0.404267  0.870224  0.330725
#
#     "XZCOR"   "YZCOR"  "RESULTANT"  "class"
# 0  0.235501  0.766845      4.04589  b'1600'
# ...

# %%
dfa.isnull().sum()
# Out:
# "ACTIVITY"     0
# "X0"           0
# "X1"           0
# "X2"           0
# "X3"           0
#               ..
# "XYCOR"        0
# "XZCOR"        0
# "YZCOR"        0
# "RESULTANT"    0
# "class"        0
# Length: 93, dtype: int64

# %%
dfg.isnull().sum()
# Out:
# "ACTIVITY"     0
# "X0"           0
# "X1"           0
# "X2"           0
# "X3"           0
#               ..
# "XYCOR"        0
# "XZCOR"        0
# "YZCOR"        0
# "RESULTANT"    0
# "class"        0
# Length: 93, dtype: int64

# %%
dfa.shape,dfg.shape
# Out:
# ((327, 93), (327, 93))

# %%
for file in all_files_accel:
    data = arff.loadarff(file)
    dfa = pd.DataFrame(data[0])
    pd.DataFrame.to_csv(dfa,"E:/desktop/project_2_data/dfa/"+file[-26:-5]+".csv")
    i=i+1

# %%
for file in all_files_gyro:
    data = arff.loadarff(file)
    dfa = pd.DataFrame(data[0])
    pd.DataFrame.to_csv(dfa,"E:/desktop/project_2_data/dfg/"+file[-26:-5]+".csv")
